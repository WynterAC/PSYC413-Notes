# %%
install.packages("effsize")
library(effsize)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
fertData <- read.csv("fertilizerTidy.csv")
fertData
# Out:
#    PlantID Height Fertilizer
# 1   55     48.2   Old
# 2   85     54.6   Old
# 3   90     58.3   Old
# 4   24     47.8   Old
# 5   28     51.4   Old
# 6   49     52.0   Old
# 7   34     55.2   Old
# 8   64     49.1   Old
# 9   31     49.9   Old
# 10  48     52.6   Old
# 11  72     52.3   New
# 12   9     57.4   New
# 13  42     55.6   New
# 14  57     53.2   New
# 15  56     61.3   New
# 16  43     58.0   New
# 17 100     59.8   New
# 18  30     54.8   New

# %%
# Cohen's d
cohen.d(Height ~ Fertilizer, data = fertData)
# Out:
# Cohen's d
#
# d estimate: 1.417542 (large)
# 95 percent confidence interval:
#     lower     upper
# 0.2941572 2.5409261

# %%
# Hedge's g
cohen.d(Height ~ Fertilizer, data = fertData, hedges.correction = TRUE)
# Out:
# Hedges's g
#
# g estimate: 1.35004 (large)
# 95 percent confidence interval:
#     lower     upper
# 0.2900813 2.4099980
