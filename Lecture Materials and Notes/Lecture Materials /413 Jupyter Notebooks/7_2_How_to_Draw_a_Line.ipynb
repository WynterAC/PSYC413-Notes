# %%
library(ggplot2)
options(repr.plot.width = 7, repr.plot.height = 5)

# %%
x <- c(1, 2, 3, 4, 5:10)
y <- 666 + 13 * x

df <- data.frame(x, y)
df
# Out:
#    x  y
# 1   1 679
# 2   2 692
# 3   3 705
# 4   4 718
# 5   5 731
# 6   6 744
# 7   7 757
# 8   8 770
# 9   9 783
# 10 10 796

# %%
ggplot(df, aes(x = x, y = y)) +
  geom_point(size = 3)
# Out:
# plot without title
