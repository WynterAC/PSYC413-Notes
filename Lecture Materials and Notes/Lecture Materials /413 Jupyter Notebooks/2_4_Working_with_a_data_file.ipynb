# %%
heightData <- read.csv("PearsonHeightData.csv")

# %%
heightData[1:10, ]
# Out:
#    Father Son
# 1  65.0   59.8
# 2  63.3   63.2
# 3  65.0   63.3
# 4  65.8   62.8
# 5  61.1   64.3
# 6  63.0   64.2
# 7  65.4   64.1
# 8  64.7   64.0
# 9  66.1   64.6
# 10 67.0   64.0

# %%
heightData$Son
# Out:
#    [1] 59.8 63.2 63.3 62.8 64.3 64.2 64.1 64.0 64.6 64.0 65.2 65.4 65.7 65.4
#   [15] 65.3 64.8 65.0 65.5 65.1 65.5 65.1 65.5 66.6 66.4 66.1 66.0 66.0 66.5
#   [29] 65.7 66.0 65.9 65.9 66.5 65.8 66.3 66.1 66.3 66.3 66.4 67.2 67.5 67.0
#   [43] 66.8 67.0 66.8 69.3 69.1 61.7 65.7 69.0 67.4 67.2 67.1 67.3 67.6 67.5
#   [57] 66.9 67.6 67.2 66.8 67.2 67.5 67.6 67.2 67.5 67.4 67.6 67.3 66.8 66.7
#   [71] 66.9 67.6 68.0 68.5 68.0 68.3 68.3 68.3 68.2 68.5 68.1 68.3 68.0 68.6
#   [85] 67.9 68.1 68.4 67.9 68.2 68.0 68.2 67.9 68.6 68.0 68.3 67.9 68.6 68.2
#   [99] 68.6 68.1 68.4 67.8 68.6 67.9 67.8 68.8 69.6 69.7 69.4 69.7 69.2 69.5
#  [113] 69.6 69.3 69.5 68.7 69.3 69.2 69.2 69.5 69.1 68.9 69.5 69.3 69.2 68.7
#  [127] 69.3 68.9 69.3 69.2 69.6 69.1 69.1 69.0 69.9 70.1 69.9 70.3 70.5 70.5
#  [141] 69.8 70.4 70.0 69.8 70.7 70.2 70.1 70.0 70.3 69.8 70.0 69.9 69.7 70.1
#  [155] 70.0 70.7 70.0 70.1 71.3 70.8 71.4 71.2 71.7 71.4 70.7 71.3 71.0 71.3
# ...

# %%
heightData$Son[666]
# Out:
# [1] 65.1

# %%
heightData[666, 2]
# Out:
# [1] 65.1

# %%
heightData$Father[c(1,3,5)]
# Out:
# [1] 65.0 65.0 61.1

# %%
heightData[c(1,3,5), 1]
# Out:
# [1] 65.0 65.0 61.1

# %%
rows <- c(1,3,5)
heightData[rows, 1]
# Out:
# [1] 65.0 65.0 61.1

# %%
pi
# Out:
# [1] 3.141593

# %%
heightData$Son_pi <- heightData$Son * pi

# %%
heightData
# Out:
#      Father Son  Son_pi
# 1    65.0   59.8 187.8672
# 2    63.3   63.2 198.5487
# 3    65.0   63.3 198.8628
# 4    65.8   62.8 197.2920
# 5    61.1   64.3 202.0044
# 6    63.0   64.2 201.6902
# 7    65.4   64.1 201.3761
# 8    64.7   64.0 201.0619
# 9    66.1   64.6 202.9469
# 10   67.0   64.0 201.0619
# 11   59.0   65.2 204.8318
# 12   62.9   65.4 205.4602
# 13   63.7   65.7 206.4026
# 14   64.1   65.4 205.4602
# 15   64.7   65.3 205.1460
# 16   65.2   64.8 203.5752
# 17   66.4   65.0 204.2035
# 18   65.6   65.5 205.7743
# 19   67.4   65.1 204.5177
# 20   66.8   65.5 205.7743
# 21   67.8   65.1 204.5177
# 22   69.5   65.5 205.7743
# 23   62.5   66.6 209.2301
# 24   63.8   66.4 208.6018
# 25   64.5   66.1 207.6593
# 26   65.0   66.0 207.3451
# 27   64.7   66.0 207.3451
# 28   65.7   66.5 208.9159
# 29   65.5   65.7 206.4026
# 30   65.6   66.0 207.3451
# ⋮    ⋮      ⋮    ⋮
# 1049 70.7   72.1 226.5088
# 1050 72.4   72.3 227.1371
# 1051 72.4   72.1 226.5088
# 1052 67.2   72.8 228.7079
# ...
