# %%
alpha = 0.05
qt(alpha, df = 4, lower.tail = FALSE)
# Out:
# [1] 2.131847

# %%
pt(2.193, df = 4, lower.tail = FALSE)
# Out:
# [1] 0.04668945

# %% [markdown]
# # R Cheat Codes: One-Sample T-test

# %%
# Data
iPhoneData <- c(53, 38, 46, 47, 43)

# %%
t.test(iPhoneData, mu = 40, alternative = c("two.sided"))
# Out:
# 	One Sample t-test
#
# data:  iPhoneData
# t = 2.1936, df = 4, p-value = 0.09332
# alternative hypothesis: true mean is not equal to 40
# 95 percent confidence interval:
#  38.56521 52.23479
# sample estimates:
# mean of x
#      45.4

# %%
t.test(iPhoneData, mu = 40, alternative = c("greater"))
# Out:
# 	One Sample t-test
#
# data:  iPhoneData
# t = 2.1936, df = 4, p-value = 0.04666
# alternative hypothesis: true mean is greater than 40
# 95 percent confidence interval:
#  40.15202      Inf
# sample estimates:
# mean of x
#      45.4
