# %%
alpha = 0.05

#Lower bound
qt(alpha/2, df = 10)

#Upper Bound
qt(alpha/2, df = 10, lower.tail = FALSE)
# Out:
# [1] -2.228139
# [1] 2.228139

# %%
pt(2.665, df = 10, lower.tail = FALSE) * 2
# Out:
# [1] 0.02369505

# %% [markdown]
# # R Cheat Codes for a Trimmed T-test

# %%
install.packages("WRS2")
library(WRS2)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘mvtnorm’, ‘reshape’, ‘plyr’, ‘mc2d’

# %%
fertData <- read.csv("fertilizerTidy.csv")

# %%
yuen(Height ~ Fertilizer, data = fertData, tr = 0.2)
# Out:
# Call:
# yuen(formula = Height ~ Fertilizer, data = fertData, tr = 0.2)
#
# Test statistic: 2.6649 (df = 10), p-value = 0.0237
#
# Trimmed mean difference:  4.86667
# 95 percent confidence interval:
# 0.7975     8.9358
#
# Explanatory measure of effect size: 0.77
