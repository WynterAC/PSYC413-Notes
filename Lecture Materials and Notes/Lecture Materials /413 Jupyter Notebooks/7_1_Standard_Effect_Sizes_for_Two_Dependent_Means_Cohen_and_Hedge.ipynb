# %%
Bright <- c(92, 91, 88, 89, 95, 86, 95, 92, 88, 88, 84, 87, 89, 87)
   Dim <- c(88, 92, 86, 84, 90, 86, 88, 90, 84, 82, 86, 84, 86, 86)

# %%
cor(Bright, Dim)
# Out:
# [1] 0.6262052

# %% [markdown]
# # R Cheat Codes

# %%
install.packages("effsize")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(effsize)

# %%
candle <- read.csv("candles.csv")
candle
# Out:
#    id readSpeed lightLvl
# 1   1 92        Bright
# 2   2 91        Bright
# 3   3 88        Bright
# 4   4 89        Bright
# 5   5 95        Bright
# 6   6 86        Bright
# 7   7 95        Bright
# 8   8 92        Bright
# 9   9 88        Bright
# 10 10 88        Bright
# 11 11 84        Bright
# 12 12 87        Bright
# 13 13 89        Bright
# 14 14 87        Bright
# 15  1 88        Dim
# 16  2 92        Dim
# 17  3 86        Dim
# 18  4 84        Dim
# 19  5 90        Dim
# 20  6 86        Dim
# 21  7 88        Dim
# 22  8 90        Dim
# 23  9 84        Dim
# 24 10 82        Dim
# 25 11 86        Dim
# 26 12 84        Dim
# 27 13 86        Dim
# 28 14 86        Dim

# %%
cohen.d(readSpeed ~ lightLvl | Subject(id), data = candle, paired = TRUE)
# Out:
# Cohen's d
#
# d estimate: 0.9136054 (large)
# 95 percent confidence interval:
#     lower     upper
# 0.3481114 1.4790993

# %%
cohen.d(readSpeed ~ lightLvl | Subject(id), 
  data = candle, 
  paired = TRUE, 
  hedges.correction = TRUE
  )
# Out:
# Hedges's g
#
# g estimate: 0.8598639 (large)
# 95 percent confidence interval:
#     lower     upper
# 0.3366582 1.3830695
