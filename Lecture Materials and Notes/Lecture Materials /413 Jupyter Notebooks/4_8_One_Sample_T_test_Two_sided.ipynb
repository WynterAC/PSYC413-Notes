# %%
alpha = 0.05

# Left Tail
qt(alpha/2, df = 4)

# Right Tail
qt(alpha/2, df = 4, lower.tail = FALSE)
# Out:
# [1] -2.776445
# [1] 2.776445

# %%
pt(2.193, df = 4, lower.tail = FALSE) * 2
# Out:
# [1] 0.0933789
