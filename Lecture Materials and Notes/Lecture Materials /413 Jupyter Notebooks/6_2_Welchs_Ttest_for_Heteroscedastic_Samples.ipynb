# %%
pt(3.013, df = 15.584, lower.tail = FALSE) * 2
# Out:
# [1] 0.00844556

# %%
alpha = 0.05

# Lower Bound
qt(alpha/2, df = 15.584)

#Upper Bound
qt(alpha/2, df = 15.584, lower.tail = FALSE)
# Out:
# [1] -2.124514
# [1] 2.124514

# %% [markdown]
# # R Cheat Code for Welch T-test

# %%
fertData <- read.csv("fertilizerTidy.csv")

# %%
t.test(Height ~ Fertilizer, data = fertData, mu = 0)
# Out:
# 	Welch Two Sample t-test
#
# data:  Height by Fertilizer
# t = 3.013, df = 15.559, p-value = 0.008458
# alternative hypothesis: true difference in means between group New and group Old is not equal to 0
# 95 percent confidence interval:
#  1.367809 7.912191
# sample estimates:
# mean in group New mean in group Old
#             56.55             51.91
