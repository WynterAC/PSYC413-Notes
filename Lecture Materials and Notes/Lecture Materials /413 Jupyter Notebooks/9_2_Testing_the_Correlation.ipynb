# %%
pt(18.94, df = 1078 - 2, lower.tail = FALSE) * 2
# Out:
# [1] 2.880214e-69

# %% [markdown]
# # R Cheat Codes

# %%
heightData <- read.csv("PearsonHeightData.csv")

# %%
cor.test(heightData$Father, heightData$Son)
# Out:
# 	Pearson's product-moment correlation
#
# data:  heightData$Father and heightData$Son
# t = 18.997, df = 1076, p-value < 2.2e-16
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.4550726 0.5445746
# sample estimates:
#       cor
# 0.5011627
