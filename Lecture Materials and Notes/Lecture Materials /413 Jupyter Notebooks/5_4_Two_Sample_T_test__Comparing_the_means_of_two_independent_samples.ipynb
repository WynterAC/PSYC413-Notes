# %%
pt(2.988, df = 16, lower.tail = FALSE) * 2
# Out:
# [1] 0.008694379

# %%
alpha = 0.05

#Lower Bound
qt(alpha/2, df = 16)

# Upper Bound
qt(alpha/2, df = 16, lower.tail = FALSE)
# Out:
# [1] -2.119905
# [1] 2.119905
